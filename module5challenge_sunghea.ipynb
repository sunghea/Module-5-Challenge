# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
mouse_metadata.head()
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0     k403     Ramicane    Male          21          16
# 1     s185    Capomulin  Female           3          17
# 2     x401    Capomulin  Female          16          15
# 3     m601    Capomulin    Male          22          17
# 4     g791     Ramicane    Male          11          16

# %%
study_results.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
# Combine the data into a single DataFrame
combined_data = pd.merge(mouse_metadata, study_results, on="Mouse ID")
# Display the data table for preview
combined_data.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
num_mice = combined_data["Mouse ID"].nunique()
num_mice
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
duplicate_mice = combined_data[combined_data.duplicated(subset=["Mouse ID", "Timepoint"])]
duplicate_mice
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mouse_ids = duplicate_mice["Mouse ID"].unique()
duplicate_mouse_ids
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse_data = combined_data[combined_data["Mouse ID"] == 'g989']
duplicate_mouse_data
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_data = combined_data.drop_duplicates(subset=["Mouse ID", "Timepoint"], keep=False)
cleaned_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
num_mice_cleaned = cleaned_data["Mouse ID"].nunique()
num_mice_cleaned
# Out:
# 249

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM 
# of the tumor volume for each regimen
summary_stats2 = cleaned_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].agg(["mean", "median", "var", "std", "sem"]).reset_index()
summary_stats2
# Out:
#   Drug Regimen       mean     median        var       std       sem
# 0    Capomulin  40.675741  41.557809  24.947764  4.994774  0.329346
# 1     Ceftamin  52.591172  51.776157  39.290177  6.268188  0.469821
# 2    Infubinol  52.884795  51.820584  43.128684  6.567243  0.492236
# 3     Ketapril  55.235638  53.698743  68.553577  8.279709  0.603860
# 4     Naftisol  54.331565  52.509285  66.173479  8.134708  0.596466
# 5      Placebo  54.033581  52.288934  61.168083  7.821003  0.581331
# 6     Propriva  52.458254  50.854632  44.053659  6.637293  0.540135
# 7     Ramicane  40.216745  40.673236  23.486704  4.846308  0.320955
# 8     Stelasyn  54.233149  52.431737  59.450562  7.710419  0.573111
# 9    Zoniferol  53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Summary Statistics

# %%
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
summary_stats = summary_stats.rename(columns={
    "mean": "Mean Tumor Volume",
    "median": "Median Tumor Volume",
    "var": "Tumor Volume Variance",
    "std": "Tumor Volume Std. Dev.",
    "sem": "Tumor Volume Std. Err."
})
summary_stats
# Out:
#   Drug Regimen  Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# 0    Capomulin          40.675741            41.557809              24.947764
# 1     Ceftamin          52.591172            51.776157              39.290177
# 2    Infubinol          52.884795            51.820584              43.128684
# 3     Ketapril          55.235638            53.698743              68.553577
# 4     Naftisol          54.331565            52.509285              66.173479
# 5      Placebo          54.033581            52.288934              61.168083
# 6     Propriva          52.458254            50.854632              44.053659
# 7     Ramicane          40.216745            40.673236              23.486704
# 8     Stelasyn          54.233149            52.431737              59.450562
# 9    Zoniferol          53.236507            51.818479              48.533355
#
#    Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# 0                4.994774                0.329346
# ...

# %%
summary_stats3 = summary_stats2.set_index("Drug Regimen")

print("                                     Tumor Volume (mm3)")
summary_stats3
# Out:
#                                      Tumor Volume (mm3)
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.458254  50.854632  44.053659  6.637293  0.540135
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
regimen_count_df = cleaned_data[["Mouse ID", "Timepoint", "Drug Regimen"]]
regimen_counts = cleaned_data.groupby("Drug Regimen").size()
regimen_counts
# Out:
# Drug Regimen
# Capomulin    230
# Ceftamin     178
# Infubinol    178
# Ketapril     188
# Naftisol     186
# Placebo      181
# Propriva     151
# Ramicane     228
# Stelasyn     181
# Zoniferol    182
# dtype: int64

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Add graph title and label
regimen_counts.plot(kind="bar", figsize=(10, 6))
plt.title("Number of Observed Mouse Timepoints for Each Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")
plt.tight_layout()
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
# Calculate the number of mice in each gender
gender_counts = cleaned_data["Sex"].value_counts()
gender_counts
# Out:
# Sex
# Male      958
# Female    925
# Name: count, dtype: int64

# %%
# Generate a pie plot 
gender_counts.plot(kind="pie", autopct='%1.1f%%', startangle=0, figsize=(8, 8))
plt.title("Distribution of Male vs. Female Mice")
plt.tight_layout()
plt.show()

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Select the treatment you need (Regimen)
selected_regimens = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
# Filter with selected treatments
final_tumor_volume = cleaned_data[cleaned_data["Drug Regimen"].isin(selected_regimens)]
final_tumor_volume
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male          21          16          0
# 1        k403     Ramicane    Male          21          16          5
# 2        k403     Ramicane    Male          21          16         10
# 3        k403     Ramicane    Male          21          16         15
# 4        k403     Ramicane    Male          21          16         20
# ...       ...          ...     ...         ...         ...        ...
# 1868     z581    Infubinol  Female          24          25         25
# 1869     z581    Infubinol  Female          24          25         30
# 1870     z581    Infubinol  Female          24          25         35
# 1871     z581    Infubinol  Female          24          25         40
# 1872     z581    Infubinol  Female          24          25         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# ...

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# final tumor volume based on the last Timepoint of each mouse
final_tumor_volume = final_tumor_volume.groupby("Mouse ID")["Timepoint"].max().reset_index()
final_tumor_volume = pd.merge(final_tumor_volume, cleaned_data, on=["Mouse ID", "Timepoint"], how="left")
final_tumor_volume
# Start by getting the last (greatest) timepoint for each mouse
last_timepoints = cleaned_data.groupby("Mouse ID")["Timepoint"].max().reset_index()
# Out:
#    Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0      a203         45    Infubinol  Female          20          23
# 1      a251         45    Infubinol  Female          21          25
# 2      a275         45     Ceftamin  Female          20          28
# 3      a411         45     Ramicane    Male           3          22
# 4      a444         45     Ramicane  Female          10          25
# ..      ...        ...          ...     ...         ...         ...
# 95     y769         45     Ceftamin  Female           6          27
# 96     y793         45    Capomulin    Male          17          17
# 97     y865         45     Ceftamin    Male          23          26
# 98     z578         45     Ramicane    Male          11          16
# 99     z581         45    Infubinol  Female          24          25
#
#     Tumor Volume (mm3)  Metastatic Sites
# 0            67.973419                 2
# 1            65.525743                 1
# ...

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Select the treatment you need (Regimen)
selected_regimens = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
# Filter with selected treatments
final_tumor_volume = cleaned_data[cleaned_data["Drug Regimen"].isin(selected_regimens)]
final_tumor_volume
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male          21          16          0
# 1        k403     Ramicane    Male          21          16          5
# 2        k403     Ramicane    Male          21          16         10
# 3        k403     Ramicane    Male          21          16         15
# 4        k403     Ramicane    Male          21          16         20
# ...       ...          ...     ...         ...         ...        ...
# 1868     z581    Infubinol  Female          24          25         25
# 1869     z581    Infubinol  Female          24          25         30
# 1870     z581    Infubinol  Female          24          25         35
# 1871     z581    Infubinol  Female          24          25         40
# 1872     z581    Infubinol  Female          24          25         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# ...

# %%
# Start by getting the last (greatest) timepoint for each mouse
last_timepoints = final_tumor_volume.groupby("Mouse ID")["Timepoint"].max().reset_index()
last_timepoints
# Out:
#    Mouse ID  Timepoint
# 0      a203         45
# 1      a251         45
# 2      a275         45
# 3      a411         45
# 4      a444         45
# ..      ...        ...
# 95     y769         45
# 96     y793         45
# 97     y865         45
# 98     z578         45
# 99     z581         45
#
# [100 rows x 2 columns]

# %%
# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
final_tumor_volume = pd.merge(last_timepoints, cleaned_data, on=["Mouse ID", "Timepoint"], how="left")
final_tumor_volume
# Out:
#    Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0      a203         45    Infubinol  Female          20          23
# 1      a251         45    Infubinol  Female          21          25
# 2      a275         45     Ceftamin  Female          20          28
# 3      a411         45     Ramicane    Male           3          22
# 4      a444         45     Ramicane  Female          10          25
# ..      ...        ...          ...     ...         ...         ...
# 95     y769         45     Ceftamin  Female           6          27
# 96     y793         45    Capomulin    Male          17          17
# 97     y865         45     Ceftamin    Male          23          26
# 98     z578         45     Ramicane    Male          11          16
# 99     z581         45    Infubinol  Female          24          25
#
#     Tumor Volume (mm3)  Metastatic Sites
# 0            67.973419                 2
# 1            65.525743                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting), outliers
tumor_volume_data = []
potential_outliers = []
# Calculate the IQR and quantitatively determine if there are any potential outliers. 

for treatment in treatments:
    # Extraction of tumor volume data for that treatment method
    treatment_data = final_tumor_volume[final_tumor_volume["Drug Regimen"] == treatment]["Tumor Volume (mm3)"]
    
    # Adding tumor volume data to the list
    tumor_volume_data.append(treatment_data)
    
    # IQR calculation
    quartiles = treatment_data.quantile([0.25, 0.75])
    lower_quartile = quartiles[0.25]
    upper_quartile = quartiles[0.75]
    iqr = upper_quartile - lower_quartile

    # Outlier boundary calculation
    lower_bound = lower_quartile - 1.5 * iqr
    upper_bound = upper_quartile + 1.5 * iqr

    # Identify and store outliers
    outliers = treatment_data[(treatment_data < lower_bound) | (treatment_data > upper_bound)]
    potential_outliers.extend(outliers)
    

print(f"tumor_volume_data: {tumor_volume_data}")
print(f"Potential Outliers: {potential_outliers }")
# Out:
# tumor_volume_data: [9     38.982878
# 12    38.939633
# 24    30.485985
# 25    37.074024
# 26    40.159220
# 32    47.685963
# 33    37.311846
# 34    38.125164
# 35    38.753265
# 45    41.483008
# 49    38.846876
# 51    28.430964
# 53    33.329098
# 64    46.539206
# 65    32.377357
# 68    41.581521
# 70    23.343598
# 72    40.728578
# 73    34.455298
# 78    31.023923
# 82    40.658124
# 83    39.952347
# 88    36.041047
# 90    28.484033
# 96    31.896238
# Name: Tumor Volume (mm3), dtype: float64, 3     38.407618
# 4     43.047543
# 5     38.810366
# 7     32.978522
# 16    38.342008
# 17    33.397653
# 19    37.311236
# 21    40.659006
# 27    29.128472
# 29    33.562402
# 30    36.374510
# 37    31.560470
# 38    36.134852
# 40    22.050126
# 50    30.564625
# 54    31.095335
# 62    45.220869
# 63    36.561652
# 66    37.225650
# 67    43.419381
# 71    30.276232
# 77    40.667713
# 87    43.166373
# 94    44.183451
# 98    30.638696
# ...

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(tumor_volume_data, labels=treatments, flierprops={'marker': 'o', 'markerfacecolor': 'red', 'markersize': 8})
plt.title("Distribution of Tumor Volume for Each Treatment Group")
plt.xlabel("Final Treatment Group")
plt.ylabel("Tumor Volume (mm3)")
plt.ylim(10, 80)  # the range of the Y-axis
plt.grid(axis='y')  # Add Grid Lines
plt.tight_layout()
plt.show()

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

# %% [markdown]
# ## Line and Scatter Plots

# %%
#Check the Mouse ID of all mice receiving "Capomulin" treatment
capomulin_mice = cleaned_data[cleaned_data["Drug Regimen"] == "Capomulin"]["Mouse ID"].unique()
capomulin_mice
# Out:
# array(['s185', 'x401', 'm601', 'f966', 'u364', 'y793', 'r554', 'm957',
#        't565', 'i738', 'w914', 'g288', 'l897', 'b742', 'b128', 'j246',
#        'j119', 'w150', 'v923', 'g316', 's710', 'l509', 'r944', 'i557',
#        'r157'], dtype=object)

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
# Select a Mouse ID 
mouse_id = "l509"

# Select data to receive Capomulin treatment
mouse_data = cleaned_data[(cleaned_data["Drug Regimen"] == "Capomulin") & (cleaned_data["Mouse ID"] == mouse_id)]
mouse_data
# Out:
#     Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 371     l509    Capomulin  Male          17          21          0
# 372     l509    Capomulin  Male          17          21          5
# 373     l509    Capomulin  Male          17          21         10
# 374     l509    Capomulin  Male          17          21         15
# 375     l509    Capomulin  Male          17          21         20
# 376     l509    Capomulin  Male          17          21         25
# 377     l509    Capomulin  Male          17          21         30
# 378     l509    Capomulin  Male          17          21         35
# 379     l509    Capomulin  Male          17          21         40
# 380     l509    Capomulin  Male          17          21         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 371           45.000000                 0
# 372           45.851193                 0
# 373           46.759074                 0
# 374           47.488599                 1
# ...

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
# Select a Mouse ID 
plt.figure(figsize=(10, 6))
plt.plot(mouse_data["Timepoint"], mouse_data["Tumor Volume (mm3)"], marker='o', linestyle='-', color='b')
plt.title(f"Tumor Volume vs. Time Point for Mouse {mouse_id} (Capomulin Treatment)")
plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume (mm3)")
plt.grid()

# %%
# Select data from all mice receiving Capomulin" therapy
capomulin_data = cleaned_data[cleaned_data["Drug Regimen"] == "Capomulin"]

# Calculate the mean tumor volume for each mouse
average_tumor_volume = capomulin_data.groupby("Mouse ID")["Tumor Volume (mm3)"].mean()

# Get weight for each mouse
mouse_weight = capomulin_data.groupby("Mouse ID")["Weight (g)"].mean()
mouse_weight
# Out:
# Mouse ID
# b128    22.0
# b742    21.0
# f966    17.0
# g288    19.0
# g316    22.0
# i557    24.0
# i738    20.0
# j119    23.0
# j246    21.0
# l509    21.0
# l897    19.0
# m601    17.0
# m957    19.0
# r157    25.0
# r554    17.0
# r944    25.0
# s185    17.0
# s710    23.0
# t565    17.0
# u364    17.0
# v923    21.0
# w150    23.0
# w914    21.0
# x401    15.0
# y793    17.0
# Name: Weight (g), dtype: float64

# %%
# Create a scatterplot
plt.figure(figsize=(10, 6))
plt.scatter(mouse_weight, average_tumor_volume, marker='o', color='b')
plt.title("Mouse Weight vs. Average Tumor Volume (Capomulin Regimen)")
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.grid()

# Graph output
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Create a scatterplot
plt.figure(figsize=(10, 6))
plt.scatter(mouse_weight, average_tumor_volume, marker='o', color='b')
plt.title("Mouse Weight vs. Average Tumor Volume (Capomulin Regimen)")
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.grid()

# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
# Linear regression model calculation
from scipy.stats import linregress
# mouse_weight, average_tumor_volume
slope, intercept, r_value, p_value, std_err = linregress(mouse_weight, average_tumor_volume)

# Create a regression line
regress_values = mouse_weight * slope + intercept
plt.plot(mouse_weight, regress_values, "r-")

# Graph Output
plt.show()


# Correlation coefficient output
print(f"Correlation Coefficient: {round(r_value,2)}")
print(f"intercept:  {round(intercept,2)}")
# Out:
# Correlation Coefficient: 0.84
# intercept:  21.55
